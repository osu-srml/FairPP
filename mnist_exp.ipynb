# %%
from MNIST_utils import *
# plotting
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib
import matplotlib.ticker as mtick
from matplotlib.ticker import FormatStrFormatter

matplotlib.rcParams['mathtext.fontset'] = 'cm'
matplotlib.rcParams['font.family'] = 'Times New Roman'

# %matplotlib inline

# %%
name = 'MNIST_v2'
rho_list = [0.1,0.3]
wd = 0.35
seeds = [12,30,31]

# %%
# regular RRM
rrm_p0_list, rrm_p1_list, rrm_l_list, rrm_ldisp_list = NN_Regular(seeds=seeds, wd=wd)
# rrm_p0_list, rrm_p1_list, rrm_l_list, rrm_ldisp_list = np.round(rrm_p0_list,3), np.round(rrm_p1_list,3), np.round(rrm_l_list,3), np.round(rrm_ldisp_list,3)
np.save(f'arrays/{name}_rrm_arrays.npy', (rrm_p0_list, rrm_p1_list, rrm_l_list, rrm_ldisp_list))

# Fair
for rho in rho_list:
    fair_p0_list, fair_p1_list, fair_l_list, fair_ldisp_list = NN_Fair(seeds=seeds,rho=rho,wd=wd)
    # fair_p0_list, fair_p1_list, fair_l_list, fair_ldisp_list = np.round(fair_p0_list,3), np.round(fair_p1_list,3), np.round(fair_l_list,3), np.round(fair_ldisp_list,3)
    np.save(f'arrays/{name}_fair_arrays_{rho}.npy', (fair_p0_list, fair_p1_list, fair_l_list, fair_ldisp_list))


# Fair without demo
for rho in rho_list:
    fair_p0_list2, fair_p1_list2, fair_l_list2, fair_ldisp_list2 = NN_Fair(seeds=seeds,rho=rho, demo='nodemo',wd=wd)
    # fair_p0_list2, fair_p1_list2, fair_l_list2, fair_ldisp_list2 = np.round(fair_p0_list2,3), np.round(fair_p1_list2,3), np.round(fair_l_list2,3), np.round(fair_ldisp_list2,3)
    np.save(f'arrays/{name}_fair_arrays2_{rho}.npy', (fair_p0_list2, fair_p1_list2, fair_l_list2, fair_ldisp_list2))

# DRO
for rho in rho_list:
    p0_list, p1_list, l_list, ldisp_list = NN_DRO(seeds=seeds,rho=rho,wd=wd)
    # p0_list, p1_list, l_list, ldisp_list = np.round(p0_list,3), np.round(p1_list,3), np.round(l_list,3), np.round(ldisp_list,3)
    np.save(f'arrays/{name}_dro_arrays_{rho}.npy', (p0_list, p1_list, l_list, ldisp_list))

# %%
# read results if needed
fair_data = np.load(f'arrays/{name}_fair_arrays_0.1.npy')
fair_p0_list, fair_p1_list, fair_l_list, fair_ldisp_list = fair_data
fair_p0_list, fair_p1_list, fair_l_list, fair_ldisp_list = np.round(fair_p0_list,3), np.round(fair_p1_list,3), np.round(fair_l_list,3), np.round(fair_ldisp_list,3)

fair_data2 = np.load(f'arrays/{name}_fair_arrays2_0.1.npy')
fair_p0_list2, fair_p1_list2, fair_l_list2, fair_ldisp_list2 = fair_data2
fair_p0_list2, fair_p1_list2, fair_l_list2, fair_ldisp_list2 = np.round(fair_p0_list2,3), np.round(fair_p1_list2,3), np.round(fair_l_list2,3), np.round(fair_ldisp_list2,3)


dro_data = np.load(f'arrays/{name}_dro_arrays_0.1.npy')
p0_list, p1_list, l_list, ldisp_list = dro_data
p0_list, p1_list, l_list, ldisp_list = np.round(p0_list,3), np.round(p1_list,3), np.round(l_list,3), np.round(ldisp_list,3)

rrm_data = np.load(f'arrays/{name}_rrm_arrays.npy')
rrm_p0_list, rrm_p1_list, rrm_l_list,rrm_ldisp_list = rrm_data
rrm_p0_list, rrm_p1_list, rrm_l_list,rrm_ldisp_list = np.round(rrm_p0_list,3), np.round(rrm_p1_list,3), np.round(rrm_l_list,3), np.round(rrm_ldisp_list,3)


# output mean and sd for these arrays
# numpy mean array
fair_p0_mean,fair_p1_mean,fair_l_mean,fair_ldisp_mean = np.mean(fair_p0_list, axis=0), np.mean(fair_p1_list, axis=0), np.mean(fair_l_list, axis=0), np.mean(fair_ldisp_list, axis=0)
fair_p0_mean2,fair_p1_mean2,fair_l_mean2,fair_ldisp_mean2 = np.mean(fair_p0_list2, axis=0), np.mean(fair_p1_list2, axis=0), np.mean(fair_l_list2, axis=0), np.mean(fair_ldisp_list2, axis=0)
rrm_p0_mean,rrm_p1_mean,rrm_l_mean,rrm_ldisp_mean = np.mean(rrm_p0_list, axis=0), np.mean(rrm_p1_list, axis=0), np.mean(rrm_l_list, axis=0),  np.mean(rrm_ldisp_list, axis=0)
p0_mean, p1_mean,l_mean,ldisp_mean = np.mean(p0_list, axis=0), np.mean(p1_list, axis=0), np.mean(l_list, axis=0), np.mean(ldisp_list, axis=0)

# numpy sd array
fair_p0_sd,fair_p1_sd,fair_l_sd,fair_ldisp_sd = np.std(fair_p0_list, axis=0), np.std(fair_p1_list, axis=0), np.std(fair_l_list, axis=0), np.std(fair_ldisp_list, axis=0)
fair_p0_sd2,fair_p1_sd2,fair_l_sd2,fair_ldisp_sd2 = np.std(fair_p0_list2, axis=0), np.std(fair_p1_list2, axis=0), np.std(fair_l_list2, axis=0), np.std(fair_ldisp_list2, axis=0)
rrm_p0_sd,rrm_p1_sd,rrm_l_sd,rrm_ldisp_sd = np.std(rrm_p0_list, axis=0), np.std(rrm_p1_list, axis=0), np.std(rrm_l_list, axis=0), np.std(rrm_ldisp_list, axis=0)
p0_sd, p1_sd,l_sd,ldisp_sd = np.std(p0_list, axis=0), np.std(p1_list, axis=0), np.std(l_list, axis=0), np.std(ldisp_list, axis=0)

# %% [markdown]
# # Convergence of performative loss

# %%
# Convergence Plot of Theta
# Create the figure and axis
fig, ax = plt.subplots(nrows=1, ncols=4, figsize = (8,1.8))
plt.subplots_adjust(wspace=-0.2) 
x = range(1,num_iter+1)
ax[0].fill_between(x, rrm_l_mean - rrm_l_sd, rrm_l_mean + rrm_l_sd, color='blue', alpha=0.2)
ax[0].plot(x, rrm_l_mean, linestyle='-', linewidth = 1, color='blue', label='RERM')
ax[1].fill_between(x, fair_l_mean - fair_l_sd, fair_l_mean + fair_l_sd, color='blue', alpha=0.2)
ax[1].plot(x, fair_l_mean, linestyle='-', linewidth = 1, color='blue', label='Fair-RERM-GLP')
ax[2].fill_between(x, fair_l_mean2 - fair_l_sd2, fair_l_mean2 + fair_l_sd2, color='blue', alpha=0.2)
ax[2].plot(x, fair_l_mean2, linestyle='-', linewidth = 1, color='blue', label='Fair-RERM-SLP')
ax[3].fill_between(x, l_mean - l_sd, l_mean + l_sd, color='blue', alpha=0.2)
ax[3].plot(x, l_mean, linestyle='-',linewidth = 1,  color='blue', label='REFRO')

# # Customize the plot
# fig.text(0.5, 0.0, 't', ha='center', fontsize=14)
# fig.text(0.07, 0.5, 'Performative loss', va='center', rotation='vertical', fontsize=12)


for a in ax:
    a.set_xlabel('t',fontsize=14)
    ax[0].set_ylabel('Performative loss',fontsize=13)
    a.legend(handlelength=0.5,fontsize=9.5)

plt.tight_layout()
plt.savefig(f'plots/{name}_loss.pdf')

# %% [markdown]
# # Dynamics of Participation Rate of the minority group
#
# - Use participation rate to measure fairness
# - For DRO, fair with/without demographic attribute, get the participation rate dynamics for different $\rho$

# %%
rrm_data = np.load(f'arrays/{name}_rrm_arrays.npy')
rrm_p0_mean = np.mean(rrm_data[1],axis=0)
rrm_p0_sd = np.std(rrm_data[1],axis=0)
dro_dict_mean, fair_dict_mean, fair_dict_mean2 = {0:rrm_p0_mean}, {0:rrm_p0_mean}, {0:rrm_p0_mean}
dro_dict_sd, fair_dict_sd, fair_dict_sd2 = {0:rrm_p0_sd}, {0:rrm_p0_sd}, {0:rrm_p0_sd}
rho_list = [0.1,0.3]
# read results if needed
for rho in rho_list:
    fair_data = np.load(f'arrays/{name}_fair_arrays_{rho}.npy')
    fair_p0_mean = np.mean(fair_data[1],axis = 0)
    fair_p0_sd = np.std(fair_data[1],axis = 0)
    fair_dict_mean[rho] = fair_p0_mean
    fair_dict_sd[rho] = fair_p0_sd

    fair_data2 = np.load(f'arrays/{name}_fair_arrays2_{rho}.npy')
    fair_p0_mean2 = np.mean(fair_data2[1],axis = 0)
    fair_p0_sd2 = np.std(fair_data2[1],axis = 0)
    fair_dict_mean2[rho] = fair_p0_mean2
    fair_dict_sd2[rho] = fair_p0_sd2

    dro_data = np.load(f'arrays/{name}_dro_arrays_{rho}.npy')
    p0_mean = np.mean(dro_data[1],axis=0)
    p0_sd = np.std(dro_data[1], axis=0)
    dro_dict_mean[rho] = p0_mean
    dro_dict_sd[rho] = p0_sd

# %%
# Convergence Plot of Theta
# Create the figure and axis
rho_list = [0.1, 0.3]
fig, ax = plt.subplots(nrows=1, ncols=3, figsize = (6,1.8))
plt.subplots_adjust(wspace=0.25) 
x = range(2,num_iter+1)
idx = range(1,num_iter)
x2 = range(1,num_iter+1)
idx2 = range(num_iter)
colors = ['blue','black','red']
rho_unicode = '\u03C1'
rho_list = [0] + rho_list
for i in range(len(rho_list)):
    color = colors[i]
    rho = rho_list[i]
    ax[0].fill_between(x, dro_dict_mean[rho][idx] - dro_dict_sd[rho][idx], dro_dict_mean[rho][idx] + dro_dict_sd[rho][idx], color=color, alpha=0.2)
    ax[0].plot(x, dro_dict_mean[rho][idx], linestyle='-', linewidth = 1, color=color, label=f'{rho_unicode} = {rho}')
    ax[1].fill_between(x, fair_dict_mean[rho][idx] - fair_dict_sd[rho][idx], fair_dict_mean[rho][idx] + fair_dict_sd[rho][idx], color=color, alpha=0.2)
    ax[1].plot(x, fair_dict_mean[rho][idx], linestyle='-', linewidth = 1, color=color, label=f'{rho_unicode} = {rho}')
    ax[2].fill_between(x2, fair_dict_mean2[rho][idx2] - fair_dict_sd2[rho][idx2], fair_dict_mean2[rho][idx2] + fair_dict_sd2[rho][idx2], color=color, alpha=0.2)
    ax[2].plot(x2, fair_dict_mean2[rho][idx2], linestyle='-', linewidth = 1, color=color, label=f'{rho_unicode} = {rho}')

for a in ax:
    a.set_xlabel(r'$t$',fontsize=12)
    ax[0].set_ylabel(r'$P$',fontsize=12)

handles, labels = [], []
for handle, label in zip(*ax[0].get_legend_handles_labels()):
    handles.append(handle)
    labels.append(label)
    
fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.55, 1.15), ncol=3, handlelength = 0.5)
plt.tight_layout()
fig.savefig(f'plots/{name}_prate.pdf',bbox_inches='tight')

# %% [markdown]
# # Dynamics of Loss disparity
#
# - Use loss disparity to measure fairness
# - For DRO, fair with/without demographic attribute, get the loss disparity dynamics for different $\rho$

# %%
rrm_data = np.load(f'arrays/{name}_rrm_arrays.npy')
ldisp_mean = np.mean(rrm_data[-1], axis=0)
ldisp_sd = np.std(rrm_data[-1], axis=0)
dro_dict_mean, fair_dict_mean, fair_dict_mean2 = {0: ldisp_mean}, {0: ldisp_mean}, {0: ldisp_mean}
dro_dict_sd, fair_dict_sd, fair_dict_sd2 = {0: ldisp_sd}, {0: ldisp_sd}, {0: ldisp_sd}
rho_list = [0.1,0.3]

# read results if needed
for rho in rho_list:
    fair_data = np.load(f'arrays/{name}_fair_arrays_{rho}.npy')
    ldisp_mean = np.mean(fair_data[-1], axis=0)
    ldisp_sd = np.std(fair_data[-1], axis=0)
    fair_dict_mean[rho] = ldisp_mean
    fair_dict_sd[rho] = ldisp_sd

    fair_data2 = np.load(f'arrays/{name}_fair_arrays2_{rho}.npy')
    ldisp_mean2 = np.mean(fair_data2[-1], axis=0)
    ldisp_sd2 = np.std(fair_data2[-1], axis=0)
    fair_dict_mean2[rho] = ldisp_mean2
    fair_dict_sd2[rho] = ldisp_sd2

    dro_data = np.load(f'arrays/{name}_dro_arrays_{rho}.npy')
    ldisp_mean = np.mean(dro_data[-1], axis=0)
    ldisp_sd = np.std(dro_data[-1], axis=0)
    dro_dict_mean[rho] = ldisp_mean
    dro_dict_sd[rho] = ldisp_sd

# %%
# Convergence Plot of Theta
# Create the figure and axis
rho_list = [0.1,0.3]
fig, ax = plt.subplots(nrows=1, ncols=3, figsize = (6,1.8))
plt.subplots_adjust(wspace=0) 
x = range(1,num_iter+1)
idx = range(num_iter)
colors = ['blue','black','red']
rho_unicode = '\u03C1'
rho_list = [0] + rho_list
for i in range(len(rho_list)):
    color = colors[i]
    rho = rho_list[i]
    ax[0].fill_between(x, dro_dict_mean[rho][idx] - dro_dict_sd[rho][idx], dro_dict_mean[rho][idx] + dro_dict_sd[rho][idx], color=color, alpha=0.2)
    ax[0].plot(x, dro_dict_mean[rho][idx], linestyle='-', linewidth = 1, color=color, label=f'{rho_unicode} = {rho}')
    ax[1].fill_between(x, fair_dict_mean[rho][idx] - fair_dict_sd[rho][idx], fair_dict_mean[rho][idx] + fair_dict_sd[rho][idx], color=color, alpha=0.2)
    ax[1].plot(x, fair_dict_mean[rho][idx], linestyle='-', linewidth = 1, color=color, label=f'{rho_unicode} = {rho}')
    ax[2].fill_between(x, fair_dict_mean2[rho][idx] - fair_dict_sd2[rho][idx], fair_dict_mean2[rho][idx] + fair_dict_sd2[rho][idx], color=color, alpha=0.2)
    ax[2].plot(x, fair_dict_mean2[rho][idx], linestyle='-', linewidth = 1, color=color, label=f'{rho_unicode} = {rho}')

for a in ax:
    # a.legend(ncol=2,handlelength=0.5)
    a.set_xlabel(r'$t$',fontsize=12)
    ax[0].set_ylabel('Loss disparity',fontsize=12)
    
handles, labels = [], []
for handle, label in zip(*ax[0].get_legend_handles_labels()):
    handles.append(handle)
    labels.append(label)
    
fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.55, 1.15), ncol=3, handlelength = 0.5)
plt.tight_layout()
fig.savefig(f'plots/{name}_ldisp.pdf',bbox_inches='tight')
